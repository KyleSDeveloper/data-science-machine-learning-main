# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt

housing = fetch_california_housing(as_frame=True)
X = housing.data
y = housing.target
X['MedInc'].hist()
# Out:
# <Axes: >

# %%
X.hist()
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>, <Axes: >]], dtype=object)

# %%
import seaborn as sns
sns.set() # this sets the default seaborn style for all plots
sns.displot(X['MedInc'], bins=50, kde=True, aspect=4)

# %%
fig, ax = plt.subplots(figsize=(25,8))
ax.hist(X['MedInc'], bins=30)
# Out:
# (array([ 148.,  588., 1511., 2251., 2496., 2689., 2382., 2123., 1593.,
#         1330.,  933.,  727.,  499.,  316.,  245.,  213.,  133.,   82.,
#           43.,   67.,   68.,   56.,   20.,   17.,   18.,   14.,   15.,
#            6.,    4.,   53.]),
#  array([ 0.4999 ,  0.98324,  1.46658,  1.94992,  2.43326,  2.9166 ,
#          3.39994,  3.88328,  4.36662,  4.84996,  5.3333 ,  5.81664,
#          6.29998,  6.78332,  7.26666,  7.75   ,  8.23334,  8.71668,
#          9.20002,  9.68336, 10.1667 , 10.65004, 11.13338, 11.61672,
#         12.10006, 12.5834 , 13.06674, 13.55008, 14.03342, 14.51676,
#         15.0001 ]),
#  <BarContainer object of 30 artists>)

# %%
fig, ax = plt.subplots()
X['MedInc'].hist(ax=ax)
ax.set_title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
from sklearn.datasets import load_iris
X,y = load_iris(return_X_y=True, as_frame=True)
X['target']=y
sns.pairplot(X, hue='target', palette='viridis');

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
import seaborn as sns

housing = fetch_california_housing(as_frame=True)
X = housing.data
corrs = X.corr()
fig, ax = plt.subplots()
sns.heatmap(corrs, ax=ax, annot=True, cmap='YlGnBu', linewidths=0.2, fmt='.2f')
ax.set_title('Correlation matrix for California Housing dataset')
# Out:
# Text(0.5, 1.0, 'Correlation matrix for California Housing dataset')

# %%
best_one = pd.read_csv('notebooks/best_one_ever_database.csv')

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(best_one, title="best_one")
profile.to_widgets()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(best_one, title="best_one")
#       4 profile.to_widgets()
#
# ModuleNotFoundError: No module named 'ydata_profiling'
